# %%
pip --version
# Out:
# pip 24.2 from c:\Tredence\pdf-extraction-mcp\.venv\Lib\site-packages\pip (python 3.13)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import AzureChatOpenAI

# Load environment variables from .env file
load_dotenv("C:/Tredence/pdf-extraction-mcp/.env")
llm = AzureChatOpenAI(
    azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT"), 
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    api_version=os.getenv("AZURE_OPENAI_API_VERSION", "2024-02-preview"),
    temperature=0.7,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)
# Out:
# C:\Users\sairamakrishna.n\AppData\Local\Temp\ipykernel_24144\2307309689.py:7: LangChainDeprecationWarning: The class `AzureChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import AzureChatOpenAI``.
#   llm = AzureChatOpenAI(

# %%
pip install -U langchain langchain-openai langchain-community
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Invoke the model
response = llm.invoke("What is LangChain and how is it used in AI?")
print(response)
# Out:
# content="LangChain is a framework designed to facilitate the development of applications powered by large language models (LLMs). It provides tools and abstractions that help developers create more complex and sophisticated AI applications by integrating language models with other data sources, processing pipelines, and external services. Here's how LangChain is typically used in AI:\n\n1. **Chaining and Orchestration**: LangChain allows developers to build chains of operations, where the output of one operation serves as the input for the next. This is particularly useful for creating multi-step AI applications that require a series of transformations or decision points.\n\n2. **Integration with Data Sources**: LangChain can connect language models with various data sources, such as databases, APIs, or local files. This enables applications to retrieve real-time data, perform lookups, and use external information to inform model outputs.\n\n3. **Enhanced Interactivity**: By using La
# ...

# %%
import os
from dotenv import load_dotenv
from langchain.embeddings import AzureOpenAIEmbeddings

# Load environment variables
load_dotenv("C:/Tredence/pdf-extraction-mcp/.env")

try:
    # Create embedder object
    embedder = AzureOpenAIEmbeddings(
        model=os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"),
        deployment=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT"),
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        api_key=os.getenv("AZURE_OPENAI_API_KEY"),
        openai_api_version=os.getenv("AZURE_OPENAI_API_VERSION"),
    )

    # Sample text for embedding
    text = "LangChain enables LLM apps using composable components."
    
    # Get embedding vector
    embedding = embedder.embed_query(text)
    
    print(f"Embedding length: {len(embedding)}")
    print(f"First 5 dimensions: {embedding[:5]}")

except Exception as e:
    print(f"Error initializing AzureOpenAIEmbeddings: {e}")
# Out:
# Error initializing AzureOpenAIEmbeddings: 'chunk_size'
# C:\Users\sairamakrishna.n\AppData\Local\Temp\ipykernel_24144\298837453.py:10: LangChainDeprecationWarning: The class `AzureOpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import AzureOpenAIEmbeddings``.
#   embedder = AzureOpenAIEmbeddings(

# %%
# Import required libraries
import os
from dotenv import load_dotenv
from langchain_openai import AzureOpenAIEmbeddings

# %%
# Load environment variables
load_dotenv("C:/Tredence/pdf-extraction-mcp/.env")
# Out:
# True

# %%
# Initialize and test embedding
try:
    embedder = AzureOpenAIEmbeddings(
        model=os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"),
        #deployment=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT"),
        azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
        api_key=os.getenv("AZURE_OPENAI_API_KEY"),
        openai_api_version="2024-12-01-preview",
         # Required in new version
    )

    # Test embedding for a single sentence
    sample_text = "LangChain enables LLM apps using composable components."
    embedding = embedder.embed_query(sample_text)

    print(f"Embedding length: {len(embedding)}")
    print(f"First 5 values: {embedding[:5]}")

except Exception as e:
    print(f"Error initializing AzureOpenAIEmbeddings: {e}")
# Out:
# Error initializing AzureOpenAIEmbeddings: 1 validation error for AzureOpenAIEmbeddings
# model
#   Input should be a valid string [type=string_type, input_value=None, input_type=NoneType]
#     For further information visit https://errors.pydantic.dev/2.11/v/string_type

# %%
! pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import os
from dotenv import load_dotenv
from langchain_openai import AzureOpenAIEmbeddings

#load_dotenv("C:/Tredence/pdf-extraction-mcp/.env")
load_dotenv()
# Debug: print to confirm
print("MODEL:", os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"))

embedder = AzureOpenAIEmbeddings(
    model=os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"),
    deployment=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT"),
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    openai_api_version="2023-05-15",
   
)

# os.environ["AZURE_OPENAI_EMBEDDING_MODEL"] = os.getenv("AZURE_OPENAI_EMBEDDING_MODEL") # or your model name
# os.environ["AZURE_OPENAI_EMBEDDING_DEPLOYMENT"] = "embedding-model"
# os.environ["AZURE_OPENAI_ENDPOINT"] = "https://llm-mlops-openai.openai.azure.com/"
# os.environ["AZURE_OPENAI_API_KEY"] = "90858d0b603c4323a2df07d8064dbcf6"
# os.environ["AZURE_OPENAI_API_VERSION"] = "2023-05-15"
# Out:
# MODEL: None
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 10
#       7 # Debug: print to confirm
#       8 print("MODEL:", os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"))
# ---> 10 embedder = AzureOpenAIEmbeddings(
#      11     model=os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"),
#      12     deployment=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT"),
#      13     azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
#      14     api_key=os.getenv("AZURE_OPENAI_API_KEY"),
#      15     openai_api_version="2023-05-15",
#      16
#      17 )
#      19 # os.environ["AZURE_OPENAI_EMBEDDING_MODEL"] = os.getenv("AZURE_OPENAI_EMBEDDING_MODEL") # or your model name
#      20 # os.environ["AZURE_OPENAI_EMBEDDING_DEPLOYMENT"] = "embedding-model"
#      21 # os.environ["AZURE_OPENAI_ENDPOINT"] = "https://llm-mlops-openai.openai.azure.com/"
# ...

# %%
# Example text
text = "Azure OpenAI is a powerfufbjfbrug fehfu or enterprise-grade LLM applications."

# Get embedding
embedding_vector = embedder1.embed_query(text)

# Show embedding
print(f"Embedding length: {len(embedding_vector)}")
print(embedding_vector[:10])  # Display first 10 values
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[2], line 5
#       2 text = "Azure OpenAI is a powerfufbjfbrug fehfu or enterprise-grade LLM applications."
#       4 # Get embedding
# ----> 5 embedding_vector = embedder1.embed_query(text)
#       7 # Show embedding
#       8 print(f"Embedding length: {len(embedding_vector)}")
#
# File c:\Tredence\pdf-extraction-mcp\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:638, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     628 def embed_query(self, text: str, **kwargs: Any) -> list[float]:
#     629     """Call out to OpenAI's embedding endpoint for embedding query text.
#     630
#     631     Args:
#    (...)    636         Embedding for the text.
#     637     """
# --> 638     return self.embed_documents([text], **kwargs)[0]
#
# ...

# %%
import os

# Set your environment variables explicitly
os.environ["AZURE_OPENAI_EMBEDDING_MODEL"] = os.getenv("AZURE_OPENAI_EMBEDDING_MODEL") # or your model name
os.environ["AZURE_OPENAI_EMBEDDING_DEPLOYMENT"] = "embedding-model"
os.environ["AZURE_OPENAI_ENDPOINT"] = "https://llm-mlops-openai.openai.azure.com/"
os.environ["AZURE_OPENAI_API_KEY"] = "90858d0b603c4323a2df07d8064dbcf6"
os.environ["AZURE_OPENAI_API_VERSION"] = "2023-05-15"

# Confirm it's set
print("MODEL:", os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"))
# Out:
# MODEL: text-embedding-3-small

# %%
embedder = AzureOpenAIEmbeddings(
    model=os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"),
    deployment=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT"),
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    api_key=os.getenv("AZURE_OPENAI_API_KEY"),
    openai_api_version=os.getenv("AZURE_OPENAI_API_VERSION")
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 embedder = AzureOpenAIEmbeddings(
#       2     model=os.getenv("AZURE_OPENAI_EMBEDDING_MODEL"),
#       3     deployment=os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT"),
#       4     azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
#       5     api_key=os.getenv("AZURE_OPENAI_API_KEY"),
#       6     openai_api_version=os.getenv("AZURE_OPENAI_API_VERSION")
#       7 )
#
# NameError: name 'AzureOpenAIEmbeddings' is not defined

# %%
# Example text
text = "Azure OpenAI is a powerful tool for enterprise-grade LLM applications."

# Get embedding
embedding_vector = embedder.embed_query(text)

# Show embedding
print(f"Embedding length: {len(embedding_vector)}")
print(embedding_vector[:10])  # Display first 10 values
# Out:
# Embedding length: 1536
# [-0.006458696443587542, 0.008267375640571117, 0.07410697638988495, 0.01873449794948101, 0.05191398784518242, -0.012098599225282669, -0.035709198564291, 0.011823630891740322, 0.023170650005340576, 0.026176968589425087]
